# %%
orig_list=[
    {"E151": "Winding wire"}, 
    {"E203": "1st Cutting Wire"},  
    {"E208": "Turn, inductance"},
    {"E200": "Wire marking"},
    {"E205": "1st peeling"},
    {"E201": "1st soldering"},
    {"E209": "Adhering pedestal, coil"},
    {"E324": "Dying adhesive"}
  ]

# %%
for i in range(0,len(orig_list)):
    old_item_code = list(orig_list[i].items())[0][0]
    print(old_item_code[1:4])

# %%
new_process = {}
